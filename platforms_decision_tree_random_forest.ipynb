# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
df = pd.read_csv("platforms.csv")
df.head()
# Out:
#               Amiga
# 0          Game Boy
# 1  Game Boy Advance
# 2         Game Gear
# 3           Genesis
# 4              Lynx

# %%
print(df.columns)

df.columns = df.columns.str.strip()  # remove spaces

if 'Platform' in df.columns:
    df['Platform'] = LabelEncoder().fit_transform(df['Platform'])
else:
    print("Column 'Platform' not found")

if 'Category' in df.columns:
    df['Category'] = LabelEncoder().fit_transform(df['Category'])
else:
    print("Column 'Category' not found")
# Out:
# Index(['Amiga'], dtype='str')
# Column 'Platform' not found
# Column 'Category' not found

# %%
print(df.columns.tolist())
# Out:
# ['Amiga']

# %%
for col in df.columns:
    print(repr(col))
# Out:
# 'Amiga'

# %%
# Find anything similar to "category"
[col for col in df.columns if 'cat' in col.lower()]
# Out:
# []

# %%
for col in df.columns:
    print(col)
# Out:
# Amiga

# %%
from sklearn.datasets import load_iris

data = load_iris()
X = data.data
y = data.target
